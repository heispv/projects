# %%
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip install importlib-metadata==4.12.0 # To overcome an issue with importlib-metadata https://stackoverflow.com/questions/73929564/entrypoints-object-has-no-attribute-get-digital-ocean
# !pip install gym[box2d]
# !pip install stable-baselines3[extra]
# !pip install huggingface_sb3
# !pip install pyglet==1.5.1
# !pip install ale-py==0.7.4 # To overcome an issue with gym (https://github.com/DLR-RM/stable-baselines3/issues/875)

# !pip install pickle5

# %%
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO, DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
import gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, done and info
  observation, reward, done, info = env.step(action)
  
  # If the game is done (in our case we land, crashed or timeout)
  if done:
      # Reset the environment
      print("Environment is reset")
      observation = env.reset()
# Out:
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 1

# %%
# We create our environment with gym.make("")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.13527271  1.068037    0.17280911 -2.7402332  -1.9746546   0.9977088
#  -2.3680027   1.776915  ]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
# Create the environment
env = make_vec_env("LunarLander-v2", n_envs=16)

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.998,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
# Train it for 2,500,000 timesteps
model.learn(total_timesteps=2500000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.7     |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    fps             | 3125     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.4         |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 2179         |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066572223 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.28e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 4.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.4         |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 2106         |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063642194 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00674     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 903          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 2.61e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.3        |
# |    ep_rew_mean          | -119        |
# | time/                   |             |
# |    fps                  | 2068        |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007573511 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00135    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 440         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 990         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.6        |
# |    ep_rew_mean          | -98.5       |
# | time/                   |             |
# |    fps                  | 2040        |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008503785 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000636   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 396         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 674         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -87.3       |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009137047 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 5.87e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 552         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.4        |
# |    ep_rew_mean          | -74.5       |
# | time/                   |             |
# |    fps                  | 1919        |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010216057 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 439         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -62.7       |
# | time/                   |             |
# |    fps                  | 1898        |
# |    iterations           | 8           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008077651 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00429    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 426         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -45.3        |
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 9            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0071503534 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.0037      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 214          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 358          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 1882        |
# |    iterations           | 10          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011472767 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.00015    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 212         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 401         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 1863        |
# |    iterations           | 11          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008655897 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000105   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 281         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 477         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -15.6       |
# | time/                   |             |
# |    fps                  | 1785        |
# |    iterations           | 12          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008516894 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.000176   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 315         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 561         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 212          |
# |    ep_rew_mean          | -8.09        |
# | time/                   |              |
# |    fps                  | 1672         |
# |    iterations           | 13           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0085892975 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 203          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 535          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | -3.65        |
# | time/                   |              |
# |    fps                  | 1591         |
# |    iterations           | 14           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0073578674 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.00456      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 306          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 510          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | 1.38        |
# | time/                   |             |
# |    fps                  | 1509        |
# |    iterations           | 15          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.005355658 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.011       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 207         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 533         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | 3.83         |
# | time/                   |              |
# |    fps                  | 1423         |
# |    iterations           | 16           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0050987545 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0408       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 428          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 491          |
# |    ep_rew_mean          | 22.2         |
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 17           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0065325913 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 323          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | 37.1        |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 18          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005478501 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 173         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 205         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 672          |
# |    ep_rew_mean          | 52           |
# | time/                   |              |
# |    fps                  | 1243         |
# |    iterations           | 19           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0049444856 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.4         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | 65.1         |
# | time/                   |              |
# |    fps                  | 1206         |
# |    iterations           | 20           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0050818333 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.8         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 124          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | 71.2        |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 21          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.004086086 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000923   |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | 74.3        |
# | time/                   |             |
# |    fps                  | 1144        |
# |    iterations           | 22          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005051853 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.2        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00056    |
# |    value_loss           | 152         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 850          |
# |    ep_rew_mean          | 76.2         |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 23           |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0062800962 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.5         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.000828    |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 842         |
# |    ep_rew_mean          | 77.6        |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 24          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006600215 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 118         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 842          |
# |    ep_rew_mean          | 76.3         |
# | time/                   |              |
# |    fps                  | 1059         |
# |    iterations           | 25           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0050222864 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.2         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000194    |
# |    value_loss           | 93.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 882          |
# |    ep_rew_mean          | 83           |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 26           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0038169348 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.2         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 81.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 891          |
# |    ep_rew_mean          | 92.5         |
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 27           |
# |    time_elapsed         | 434          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0056499485 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.2          |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 21.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 912          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 997          |
# |    iterations           | 28           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0047434913 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 67.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 983         |
# |    iterations           | 29          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.006025204 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.000874   |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 30           |
# |    time_elapsed         | 507          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0056414735 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.6         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.000104    |
# |    value_loss           | 41.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 31          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.007017771 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.5         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000746   |
# |    value_loss           | 31.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 32           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0061445516 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.77         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000197    |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 958          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 938          |
# |    iterations           | 33           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0044337213 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.77         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000736    |
# |    value_loss           | 19.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 34          |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.006959219 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.74        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 31.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 35          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.005652817 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.05        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.000799   |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 36          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.003714974 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0006      |
# |    value_loss           | 8.96        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | 133        |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 37         |
# |    time_elapsed         | 660        |
# |    total_timesteps      | 606208     |
# | train/                  |            |
# |    approx_kl            | 0.00449782 |
# |    clip_fraction        | 0.041      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.946     |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.2        |
# |    n_updates            | 144        |
# |    policy_gradient_loss | 0.000116   |
# |    value_loss           | 24.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 949          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 38           |
# |    time_elapsed         | 681          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0046552503 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.931       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 37.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 964          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 910          |
# |    iterations           | 39           |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0036641497 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.000112     |
# |    value_loss           | 22.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 964        |
# |    ep_rew_mean          | 143        |
# | time/                   |            |
# |    fps                  | 908        |
# |    iterations           | 40         |
# |    time_elapsed         | 721        |
# |    total_timesteps      | 655360     |
# | train/                  |            |
# |    approx_kl            | 0.00528289 |
# |    clip_fraction        | 0.0591     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.04       |
# |    n_updates            | 156        |
# |    policy_gradient_loss | -0.000613  |
# |    value_loss           | 20.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 41           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0044087647 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.91         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 4.83         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 952          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 903          |
# |    iterations           | 42           |
# |    time_elapsed         | 761          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0027876783 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.44         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | 5.09e-05     |
# |    value_loss           | 33.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 943          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 901          |
# |    iterations           | 43           |
# |    time_elapsed         | 781          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0043945727 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.889       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.74         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 22.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 900          |
# |    iterations           | 44           |
# |    time_elapsed         | 800          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0024424302 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000522    |
# |    value_loss           | 51.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 910         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 45          |
# |    time_elapsed         | 819         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.003160352 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000171   |
# |    value_loss           | 39          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 896          |
# |    iterations           | 46           |
# |    time_elapsed         | 840          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0032640751 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000698    |
# |    value_loss           | 51.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 900         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 47          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.003111781 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000452   |
# |    value_loss           | 34.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 901         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 48          |
# |    time_elapsed         | 879         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.003597251 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.6        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | 8.15e-05    |
# |    value_loss           | 44.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 49          |
# |    time_elapsed         | 900         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.004628507 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | 0.000209    |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 933        |
# |    ep_rew_mean          | 136        |
# | time/                   |            |
# |    fps                  | 889        |
# |    iterations           | 50         |
# |    time_elapsed         | 920        |
# |    total_timesteps      | 819200     |
# | train/                  |            |
# |    approx_kl            | 0.00463368 |
# |    clip_fraction        | 0.03       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.91      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.98       |
# |    n_updates            | 196        |
# |    policy_gradient_loss | -0.000594  |
# |    value_loss           | 20.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 51           |
# |    time_elapsed         | 941          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0028662393 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000772    |
# |    value_loss           | 3.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 52           |
# |    time_elapsed         | 963          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0034723303 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.82         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 35.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 53           |
# |    time_elapsed         | 982          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0032150298 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.6         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000357    |
# |    value_loss           | 62.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 54           |
# |    time_elapsed         | 1002         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0040866993 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.94         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 0.00081      |
# |    value_loss           | 3.73         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 936          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 55           |
# |    time_elapsed         | 1021         |
# |    total_timesteps      | 901120       |
# ...
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 136          |
# |    time_elapsed         | 2005         |
# |    total_timesteps      | 2228224      |
# | train/                  |              |
# |    approx_kl            | 0.0029016067 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.624       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.57         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -4.01e-05    |
# |    value_loss           | 7.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 137          |
# |    time_elapsed         | 2015         |
# |    total_timesteps      | 2244608      |
# | train/                  |              |
# |    approx_kl            | 0.0046673073 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 544          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 155          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 222          |
# |    ep_rew_mean          | 270          |
# | time/                   |              |
# |    fps                  | 1116         |
# |    iterations           | 138          |
# |    time_elapsed         | 2025         |
# |    total_timesteps      | 2260992      |
# | train/                  |              |
# |    approx_kl            | 0.0028745788 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 548          |
# |    policy_gradient_loss | 9.31e-05     |
# |    value_loss           | 95.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 220          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 1118         |
# |    iterations           | 139          |
# |    time_elapsed         | 2035         |
# |    total_timesteps      | 2277376      |
# | train/                  |              |
# |    approx_kl            | 0.0037657348 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 552          |
# |    policy_gradient_loss | -1.8e-05     |
# |    value_loss           | 199          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 140         |
# |    time_elapsed         | 2046        |
# |    total_timesteps      | 2293760     |
# | train/                  |             |
# |    approx_kl            | 0.003759928 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.49        |
# |    n_updates            | 556         |
# |    policy_gradient_loss | 0.00131     |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 141          |
# |    time_elapsed         | 2056         |
# |    total_timesteps      | 2310144      |
# | train/                  |              |
# |    approx_kl            | 0.0044011045 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | 0.000209     |
# |    value_loss           | 70.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 1125        |
# |    iterations           | 142         |
# |    time_elapsed         | 2067        |
# |    total_timesteps      | 2326528     |
# | train/                  |             |
# |    approx_kl            | 0.004525467 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 564         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 135         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 218          |
# |    ep_rew_mean          | 281          |
# | time/                   |              |
# |    fps                  | 1127         |
# |    iterations           | 143          |
# |    time_elapsed         | 2077         |
# |    total_timesteps      | 2342912      |
# | train/                  |              |
# |    approx_kl            | 0.0048492206 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 278          |
# |    n_updates            | 568          |
# |    policy_gradient_loss | -0.000526    |
# |    value_loss           | 169          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 219         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 144         |
# |    time_elapsed         | 2087        |
# |    total_timesteps      | 2359296     |
# | train/                  |             |
# |    approx_kl            | 0.003969874 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93        |
# |    n_updates            | 572         |
# |    policy_gradient_loss | 0.000246    |
# |    value_loss           | 8.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 1132        |
# |    iterations           | 145         |
# |    time_elapsed         | 2097        |
# |    total_timesteps      | 2375680     |
# | train/                  |             |
# |    approx_kl            | 0.002439897 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 203         |
# |    n_updates            | 576         |
# |    policy_gradient_loss | -0.000482   |
# |    value_loss           | 366         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 212          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 146          |
# |    time_elapsed         | 2107         |
# |    total_timesteps      | 2392064      |
# | train/                  |              |
# |    approx_kl            | 0.0033710129 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.000285     |
# |    value_loss           | 96.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 221        |
# |    ep_rew_mean          | 273        |
# | time/                   |            |
# |    fps                  | 1137       |
# |    iterations           | 147        |
# |    time_elapsed         | 2117       |
# |    total_timesteps      | 2408448    |
# | train/                  |            |
# |    approx_kl            | 0.00326559 |
# |    clip_fraction        | 0.0422     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.588     |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.6        |
# |    n_updates            | 584        |
# |    policy_gradient_loss | 0.000491   |
# |    value_loss           | 62.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 1139         |
# |    iterations           | 148          |
# |    time_elapsed         | 2128         |
# |    total_timesteps      | 2424832      |
# | train/                  |              |
# |    approx_kl            | 0.0036032388 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 588          |
# |    policy_gradient_loss | -0.000284    |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 1141         |
# |    iterations           | 149          |
# |    time_elapsed         | 2138         |
# |    total_timesteps      | 2441216      |
# | train/                  |              |
# |    approx_kl            | 0.0034065093 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 592          |
# |    policy_gradient_loss | 0.000882     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 210          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 1143         |
# |    iterations           | 150          |
# |    time_elapsed         | 2148         |
# |    total_timesteps      | 2457600      |
# | train/                  |              |
# |    approx_kl            | 0.0035618288 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.73         |
# |    n_updates            | 596          |
# |    policy_gradient_loss | 9.66e-05     |
# |    value_loss           | 111          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 1146         |
# |    iterations           | 151          |
# |    time_elapsed         | 2158         |
# |    total_timesteps      | 2473984      |
# | train/                  |              |
# |    approx_kl            | 0.0032736042 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.595       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 267          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 216          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 152          |
# |    time_elapsed         | 2169         |
# |    total_timesteps      | 2490368      |
# | train/                  |              |
# |    approx_kl            | 0.0043222904 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.5         |
# |    n_updates            | 604          |
# |    policy_gradient_loss | -0.000534    |
# |    value_loss           | 189          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 219          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 1149         |
# |    iterations           | 153          |
# |    time_elapsed         | 2180         |
# |    total_timesteps      | 2506752      |
# | train/                  |              |
# |    approx_kl            | 0.0036323988 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 204          |
# |    n_updates            | 608          |
# |    policy_gradient_loss | -5.92e-05    |
# |    value_loss           | 200          |
# ------------------------------------------

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=272.13 +/- 15.44387302647477

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
import gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id = "heispv/ppo-LunarLander-v2"

# TODO: Define the name of the environment
env_id = "LunarLander-v2"

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])


# TODO: Define the model architecture we used
model_architecture = "PPO"

## TODO: Define the commit message
commit_message = "Uploading the PPO agent for LunarLander-v2 environment"

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)

# Note: if after running the package_to_hub function and it gives an issue of rebasing, please run the following code
# cd <path_to_repo> && git add . && git commit -m "Add message" && git pull
# And don't forget to do a "git push" at the end to push the change to the hub.
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmppnsd58sm/-step-0-to-step-1000.mp4
# ℹ Pushing repo heispv/ppo-LunarLander-v2 to the Hugging Face Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/heispv/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/heispv/ppo-LunarLander-v2/tree/main/'
